# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
A = pd.read_csv("Hyper.csv")

# %%
A.drop(columns=["Unnamed: 0"])
# Out:
#                               RandomForestClassifier  \
# 0                        [0.64, 0.638, 0.647, 0.644]
# 1  [0.7094430992736077, 0.7234530175706646, 0.723...
# 2  [0.6181434599156118, 0.6062740076824584, 0.616...
# 3  [0.8323863636363636, 0.896780303030303, 0.8759...
#
#                                   LogisticRegression  \
# 0                      [0.7175, 0.706, 0.692, 0.672]
# 1  [0.7565704437742351, 0.7529411764705882, 0.743...
# 2  [0.6940711462450593, 0.676737160120846, 0.6639...
# 3  [0.8314393939393939, 0.8484848484848485, 0.843...
#
#                                 KNeighborsClassifier
# 0                   [0.6735, 0.6705, 0.6655, 0.6685]
# 1  [0.6822384428223843, 0.6796305298979097, 0.673...
# 2  [0.7017017017017017, 0.6983016983016983, 0.694...
# 3  [0.6638257575757576, 0.6619318181818182, 0.654...

# %%
a=A['RandomForestClassifier']
b=A['LogisticRegression']
c=A['KNeighborsClassifier']

# %%
modes = [2,3,4,5,6,7,8,9,10]

# %%
models_acc = [[0.64, 0.638, 0.647, 0.644,0.655, 0.6595, 0.651, 0.653, 0.6465],[0.7175, 0.706, 0.692, 0.672,0.6845, 0.6975, 0.6775, 0.6845, 0.681],[0.6735, 0.6705, 0.6655, 0.6685,0.6645, 0.6795, 0.6705, 0.6745, 0.6735]]
models_f1 = [[0.7094430992736077, 0.7234530175706646, 0.7237871674491393, 0.7282442748091603,0.721324717285945, 0.7203285420944558, 0.7216905901116427, 0.7183441558441559, 0.7143434343434344],[0.7565704437742351, 0.7529411764705882, 0.7431192660550459, 0.7369687249398557,0.7397938144329896, 0.7448334036271614, 0.7389720760825577, 0.7433916226108174, 0.7408610885458977],[0.6822384428223843, 0.6796305298979097, 0.673817649926865, 0.684135302525012,0.6543019062339002, 0.6847024102311855, 0.6845380564863571, 0.6939351198871649, 0.6994937873907041]]
models_pre = [[0.6181434599156118, 0.6062740076824584, 0.6166666666666667, 0.6099744245524297,0.6288732394366198, 0.6359680928208847, 0.6232782369146006, 0.6285511363636364, 0.6229739252995067],[0.6940711462450593, 0.676737160120846, 0.6639344262295082, 0.6390820584144645,0.6552227903579255, 0.6714828897338403, 0.6452296819787986, 0.6514611546685674, 0.6486486486486487],[0.7017017017017017, 0.6983016983016983, 0.6944723618090453, 0.6883988494726749,0.7175141242937854, 0.7123848515864892, 0.6921587608906099, 0.6890756302521008, 0.6803939122649956]]
models_re = [[0.8323863636363636, 0.896780303030303, 0.8759469696969697, 0.9034090909090909,0.8456439393939394, 0.8304924242424242, 0.8570075757575758, 0.8380681818181818, 0.8371212121212122],[0.8314393939393939, 0.8484848484848485, 0.84375, 0.8702651515151515,0.8494318181818182, 0.8361742424242424, 0.8645833333333334, 0.865530303030303, 0.8636363636363636],[0.6638257575757576, 0.6619318181818182, 0.6543560606060606, 0.6799242424242424,0.6013257575757576, 0.6590909090909091, 0.6770833333333334, 0.6988636363636364, 0.7196969696969697]]

# %%
plt.plot(modes,models_acc[0])
plt.plot(modes,models_acc[1])
plt.plot(modes,models_acc[2])
plt.legend(["RandomForestClassifier",'LogisticRegression','KNeighborsClassifier'])
plt.title("Accuracy")
plt.show()

# %%
plt.plot(modes,models_f1[0])
plt.plot(modes,models_f1[1])
plt.plot(modes,models_f1[2])
plt.legend(["RandomForestClassifier",'LogisticRegression','KNeighborsClassifier'])
plt.title("F1-Score")
plt.show()

# %%
plt.plot(modes,models_pre[0])
plt.plot(modes,models_pre[1])
plt.plot(modes,models_pre[2])
plt.legend(["RandomForestClassifier",'LogisticRegression','KNeighborsClassifier'])
plt.title("Precision")
plt.show()

# %%
plt.plot(modes,models_re[0])
plt.plot(modes,models_re[1])
plt.plot(modes,models_re[2])
plt.legend(["RandomForestClassifier",'LogisticRegression','KNeighborsClassifier'])
plt.title("Recall")
plt.show()

# %% [markdown]
# ## Alpha

# %%
acc = [[0.648, 0.6435, 0.6435, 0.638, 0.6435, 0.6465, 0.6465, 0.6415, 0.64, 0.6425, 0.641, 0.6345, 0.637, 0.6405, 0.633, 0.6335],[0.687, 0.674, 0.657, 0.647, 0.6385, 0.6445, 0.637, 0.6385, 0.6405, 0.6395, 0.637, 0.636, 0.6345, 0.6315, 0.6325, 0.6305],[0.658, 0.6555, 0.6445, 0.655, 0.6675, 0.665, 0.6505, 0.6495, 0.653, 0.6525, 0.648, 0.6545, 0.654, 0.649, 0.648, 0.6485]]
f1 = [[0.7271317829457364, 0.7235362543621557, 0.7222438644331904, 0.718944099378882, 0.7209393346379648, 0.7213243988963342, 0.7217630853994491, 0.7202497073741709, 0.7176470588235295, 0.7199373286329808, 0.7190923317683882, 0.7132208709297764, 0.7161845191555903, 0.7185909980430527, 0.7130570758405004, 0.7133359405553383],[0.7446982055464926, 0.7383627608346709, 0.7303459119496855, 0.724863600935308, 0.7194412107101281, 0.7251642829532278, 0.7231121281464531, 0.7254082795290542, 0.727134724857685, 0.7263757115749525, 0.7252081756245269, 0.7246596066565809, 0.7244628722201282, 0.7222012815680363, 0.7242026266416511, 0.7231172723866617],[0.666015625, 0.6620892594409025, 0.6516413522782949, 0.6754468485418627, 0.6911286576869485, 0.6860356138706655, 0.669190724088973, 0.6722767648433848, 0.6738721804511278, 0.6768944676894468, 0.6737720111214087, 0.6799444187123669, 0.6808118081180812, 0.6759002770083103, 0.6761729530818769, 0.6749884419787332]]
pre = [[0.615485564304462, 0.6126066973079448, 0.613500992720053, 0.6092105263157894, 0.6144096064042696, 0.6178257933828494, 0.6175084175084176, 0.6124751161247511, 0.6124497991967871, 0.6138944555778223, 0.6126666666666667, 0.608841259209645, 0.6098535286284953, 0.6124082721814543, 0.607190412782956, 0.6075949367088608],[0.6540114613180515, 0.6406685236768802, 0.6243279569892473, 0.6158940397350994, 0.6094674556213018, 0.6126714565643371, 0.6053639846743295, 0.605580215599239, 0.6067131095630146, 0.6060797973400887, 0.6040353089533418, 0.6032745591939547, 0.6017532874139011, 0.5998747651847214, 0.5997513983840895, 0.5982641041537508],[0.6875, 0.6866734486266531, 0.6751269035532995, 0.6710280373831776, 0.6782133090246126, 0.6790352504638218, 0.6688741721854304, 0.6638965835641736, 0.6688432835820896, 0.6648401826484018, 0.6597096188747731, 0.6654578422484134, 0.6636690647482014, 0.6594594594594595, 0.6574239713774598, 0.6594399277326106]]
re = [[0.8882575757575758, 0.8835227272727273, 0.8778409090909091, 0.8768939393939394, 0.8721590909090909, 0.8664772727272727, 0.8683712121212122, 0.8740530303030303, 0.8664772727272727, 0.8702651515151515, 0.8702651515151515, 0.8607954545454546, 0.8674242424242424, 0.8693181818181818, 0.8636363636363636, 0.8636363636363636],[0.8645833333333334, 0.8712121212121212, 0.8797348484848485, 0.8806818181818182, 0.8778409090909091, 0.8882575757575758, 0.8977272727272727, 0.9043560606060606, 0.9071969696969697, 0.90625, 0.9071969696969697, 0.9071969696969697, 0.9100378787878788, 0.9071969696969697, 0.9138257575757576, 0.9138257575757576],[0.6458333333333334, 0.6392045454545454, 0.6297348484848485, 0.6799242424242424, 0.7045454545454546, 0.6931818181818182, 0.6695075757575758, 0.6808712121212122, 0.6789772727272727, 0.6893939393939394, 0.6884469696969697, 0.6950757575757576, 0.6988636363636364, 0.6931818181818182, 0.6960227272727273, 0.6912878787878788]]

# %%
a = range(100,4000,250)

# %%
plt.plot(a,acc[0])
plt.plot(a,acc[1])
plt.plot(a,acc[2])
plt.legend(["RandomForestClassifier",'LogisticRegression','KNeighborsClassifier'])
plt.title("Accuracy")
plt.show()

# %%
plt.plot(a,f1[0])
plt.plot(a,f1[1])
plt.plot(a,f1[2])
plt.legend(["RandomForestClassifier",'LogisticRegression','KNeighborsClassifier'])
plt.title("F1")
plt.show()

# %%
plt.plot(a,pre[0])
plt.plot(a,pre[1])
plt.plot(a,pre[2])
plt.legend(["RandomForestClassifier",'LogisticRegression','KNeighborsClassifier'])
plt.title("Precision")
plt.show()

# %%
plt.plot(a,re[0])
plt.plot(a,re[1])
plt.plot(a,re[2])
plt.legend(["RandomForestClassifier",'LogisticRegression','KNeighborsClassifier'])
plt.title("Recall")
plt.show()

# %%
acc = [[0.638, 0.6435, 0.647, 0.6535, 0.6525],[0.706, 0.6905, 0.6915, 0.6875, 0.688],[0.6705, 0.66, 0.656, 0.6525, 0.655]]
f1 = [[0.7234530175706646, 0.7281738467403736, 0.728878648233487, 0.7312911981388134, 0.7305157037611477],[0.7529411764705882, 0.7466230045026605, 0.7464036169338266, 0.7439573945104465, 0.7450980392156864],[0.6796305298979097, 0.6692607003891049, 0.6647173489278753, 0.6611409068746953, 0.661432777232581]]
pre = [[0.6062740076824584, 0.6094447989789407, 0.6130490956072352, 0.6191726854891662, 0.618516086671044],[0.676737160120846, 0.6575342465753424, 0.6594045025417574, 0.6555956678700361, 0.6551724137931034],[0.6983016983016983, 0.688, 0.6847389558232931, 0.6814070351758794, 0.6863543788187373]] 
re = [[0.896780303030303, 0.9043560606060606, 0.8986742424242424, 0.8929924242424242, 0.8920454545454546],[0.8484848484848485, 0.8636363636363636, 0.8598484848484849, 0.8598484848484849, 0.8636363636363636],[0.6619318181818182, 0.6515151515151515, 0.6458333333333334, 0.6420454545454546, 0.6382575757575758]]

# %%
a = range(1,100,20)

# %%
plt.plot(a,acc[0])
plt.plot(a,acc[1])
plt.plot(a,acc[2])
plt.legend(["RandomForestClassifier",'LogisticRegression','KNeighborsClassifier'])
plt.title("Accuracy")
plt.show()

# %%
plt.plot(a,f1[0])
plt.plot(a,f1[1])
plt.plot(a,f1[2])
plt.legend(["RandomForestClassifier",'LogisticRegression','KNeighborsClassifier'])
plt.title("F1")
plt.show()

# %%
plt.plot(a,pre[0])
plt.plot(a,pre[1])
plt.plot(a,pre[2])
plt.legend(["RandomForestClassifier",'LogisticRegression','KNeighborsClassifier'])
plt.title("Precision")
plt.show()

# %%
plt.plot(a,re[0])
plt.plot(a,re[1])
plt.plot(a,re[2])
plt.legend(["RandomForestClassifier",'LogisticRegression','KNeighborsClassifier'])
plt.title("Recall")
plt.show()

# %%
acc = [[0.638, 0.64, 0.64, 0.636, 0.638, 0.638, 0.64, 0.6425, 0.639, 0.637, 0.6395, 0.6365, 0.6375, 0.6375, 0.6355, 0.6395, 0.642, 0.643, 0.639],[0.706, 0.706, 0.698, 0.701, 0.696, 0.691, 0.6905, 0.685, 0.6885, 0.69, 0.689, 0.688, 0.687, 0.6875, 0.6885, 0.6895, 0.691, 0.6915, 0.6915],[0.6705, 0.665, 0.668, 0.674, 0.672, 0.666, 0.6635, 0.6645, 0.662, 0.6605, 0.6615, 0.663, 0.6625, 0.66, 0.658, 0.659, 0.6595, 0.6595, 0.6595]]
f1 =[[0.7234530175706646, 0.7258187357197259, 0.7270659590598939, 0.7240333586050038, 0.7234530175706646, 0.7253414264036419, 0.7264437689969605, 0.7284466388150399, 0.7265151515151516, 0.725, 0.7261678693505508, 0.7236792094260738, 0.724648689707558, 0.724648689707558, 0.7237589996210685, 0.72595971113645, 0.7277566539923954, 0.7281035795887282, 0.7258921791951405],[0.7529411764705882, 0.7562189054726368, 0.751440329218107, 0.7541118421052632, 0.7472984206151287, 0.7452596867271227, 0.7466230045026605, 0.7413793103448276, 0.7437268613739202, 0.7452752670501233, 0.7442434210526316, 0.7440525020508614, 0.7436527436527436, 0.7441670077773231, 0.7447767308480131, 0.745804338927548, 0.7469287469287469, 0.7476482617586913, 0.7474416700777733],[0.6796305298979097, 0.6766409266409266, 0.6798457087753135, 0.6847195357833655, 0.6846153846153845, 0.6763565891472868, 0.6747220879652006, 0.6750605326876514, 0.6721629485935985, 0.6705482775351771, 0.6705596107055961, 0.6718597857838364, 0.6708922476840565, 0.6686159844054582, 0.6669912366114897, 0.6679649464459592, 0.668290306867998, 0.668290306867998, 0.6686131386861314]]
pre=[[0.6062740076824584, 0.6070063694267516, 0.6061946902654868, 0.6036662452591656, 0.6062740076824584, 0.6050632911392405, 0.6065989847715736, 0.6081166772352569, 0.6054292929292929, 0.6041666666666666, 0.6062143310082435, 0.6044444444444445, 0.6049461001902346, 0.6049461001902346, 0.6032849020846494, 0.6063492063492063, 0.6080050825921219, 0.6089171974522293, 0.605830164765526],[0.676737160120846, 0.672566371681416, 0.6644832605531296, 0.6664244186046512, 0.6659259259259259, 0.6598540145985401, 0.6575342465753424, 0.6543478260869565, 0.6574545454545454, 0.658200290275762, 0.657703488372093, 0.6562952243125905, 0.6551226551226551, 0.6553713049747657, 0.6563176895306859, 0.6568132660418169, 0.658008658008658, 0.6580273578113751, 0.6582552271088681],[0.6983016983016983, 0.6899606299212598, 0.6925343811394892, 0.6996047430830039, 0.6953125, 0.6924603174603174, 0.6890424481737414, 0.6907829534192269, 0.6888667992047713, 0.6875621890547263, 0.6896896896896897, 0.6913827655310621, 0.6914572864321608, 0.6887550200803213, 0.6863727454909819, 0.687374749498998, 0.6880641925777332, 0.6880641925777332, 0.6876876876876877]]
re=[[0.896780303030303, 0.9024621212121212, 0.9081439393939394, 0.9043560606060606, 0.896780303030303, 0.9053030303030303, 0.9053030303030303, 0.9081439393939394, 0.9081439393939394, 0.90625, 0.9053030303030303, 0.9015151515151515, 0.9034090909090909, 0.9034090909090909, 0.9043560606060606, 0.9043560606060606, 0.90625, 0.9053030303030303, 0.9053030303030303],[0.8484848484848485, 0.8636363636363636, 0.8645833333333334, 0.8683712121212122, 0.8513257575757576, 0.8560606060606061, 0.8636363636363636, 0.8551136363636364, 0.8560606060606061, 0.8589015151515151, 0.8570075757575758, 0.8589015151515151, 0.8598484848484849, 0.8607954545454546, 0.8607954545454546, 0.8626893939393939, 0.8636363636363636, 0.865530303030303, 0.8645833333333334],[0.6619318181818182, 0.6638257575757576, 0.6676136363636364, 0.6704545454545454, 0.6742424242424242, 0.6609848484848485, 0.6609848484848485, 0.6600378787878788, 0.65625, 0.6543560606060606, 0.6524621212121212, 0.6534090909090909, 0.6515151515151515, 0.6496212121212122, 0.6486742424242424, 0.6496212121212122, 0.6496212121212122, 0.6496212121212122, 0.6505681818181818]]

# %%
a = range(1,20)

# %%
plt.plot(a,acc[0])
plt.plot(a,acc[1])
plt.plot(a,acc[2])
plt.legend(["RandomForestClassifier",'LogisticRegression','KNeighborsClassifier'])
plt.title("Accuracy")
plt.xticks(a)
plt.show()

# %%
plt.plot(f1[0])
plt.plot(f1[1])
plt.plot(f1[2])
plt.legend(["RandomForestClassifier",'LogisticRegression','KNeighborsClassifier'])
plt.title("F1-Score")
plt.xticks(a)
plt.show()

# %%
plt.plot(pre[0])
plt.plot(pre[1])
plt.plot(pre[2])
plt.legend(["RandomForestClassifier",'LogisticRegression','KNeighborsClassifier'])
plt.title("Precision")
plt.xticks(a)
plt.show()

# %%
plt.plot(re[0])
plt.plot(re[1])
plt.plot(re[2])
plt.legend(["RandomForestClassifier",'LogisticRegression','KNeighborsClassifier'])
plt.title("Recall")
plt.xticks(a)
plt.show()
